# %% [markdown]
# # Tercer Proyecto: Analisis exploratorio de un dataset
#
# En este proyecto deberán seleccionar un conjunto de datos de su interés, con cualquiera de las fuentes de datos mostradas o alguna otra fuente de datos, incluso valen datos recolectados por ustedes. Deberan explorar los datos con el finde hacer una pregunta que puedan responder usando algoritmos de aprendizaje automático.

# %% [markdown]
# # Tema que van a abordar

# %% [markdown]
# La tematica del proyecto se basa en la probabilidad de tocar o cliquear un anuncio publicitario y terminar comprando el producto, con factores dependientes como la edad, los ingresos anuales o el sexo de la persona en cuestion.
#
# Elegimos esta tematica, ya que, nos resulto simpatica e interesente, ademas, analizar este tema nos ayuda a sacarnos la duda de quienes son o quien es el publico que generalmente ve las publicidades y compra por internet. Lo mencionado anteriormente; el analizar este tipo de cuestiones nos puede ayudar en un futuro a direccionar mejor nuestra campaña publicitaria y elegir rigurosamente con un modelo de prediccion si nuestro publico al que apuntamos es acorde.

# %%
#Una vez presentado el proyecto, subimos el archivo sobre el cual vamos a trabajar
from google.colab import files

SubirArchivo = files.upload()
# Out:
#      <input type="file" id="files-49aee816-bd12-4430-8744-deebd880e6af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-49aee816-bd12-4430-8744-deebd880e6af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Social_Network_Ads.csv to Social_Network_Ads.csv

# %%
#Cargamos la libreria de pandas que es muy util porque agrega muchas funciones
import pandas as pd

#Cargamos una variable que contenga el archivo que acabamos de subir
Ad = pd.read_csv("Social_Network_Ads.csv")

# %% [markdown]
# # Definición del problema
#
# ¿Cuál es la pregunta que queremos resolver? Es importante que la misma sea lo más específica posible para usar la misma como guía. Es muy fácil perder el foco y terminar generando otra respuesta.
#
# También es de valor un poco de contexto sobre la pregunta ¿cómo surgió? ¿Por qué escogiste esa pregunta?

# %% [markdown]
# Las preguntas que nos hacemos al hallar este conjunto de datos, son las siguientes:
#
# **¿Las mujeres compran mas que los hombres al ver anuncios?**
#
# En resumen, se nos ocurre que esta pregunta puede ser clave para direccionar la venta de un producto dependiendo del sexo. Ademas, servira para ver quienes son los que en la mayoria de las ocasiones compran productos por internet o utilizan las herramientas que brindan los anuncios publicitarios.
#
# **¿Las personas con un salario mas alto se interesan mas por productos o saben administrar su dinero?**
#
# Escogimos esta, porque, parece algo obvio, pero, cuando analizas el transfondo de la pregunta te pueden salir variables que antes no tenias en cuenta que hacen cambiar tu forma de pensar, por lo tanto, las personas que ganan mas, ¿administraran mejor su dinero y tiempo, o los gastaran mas?
#
# **¿Quienes compran mas, los mayores o los jovenes?**
#
# Simplemente pensamos que las personas en torno a una edad en donde se considera que pueden llegar a poseer una familia cliquearian mas por el hecho de que hacen mas compras al tener niños a cargo que todavia no poseen el poder de decidir sobre su compra.

# %% [markdown]
# # Búsqueda de datos
#
# ¿Qué datos usarás para resolver tu pregunta? En esta sección se deben de describir los mismos, no desde un punto de vista de análisis exploratorio, sino más enfocado en la búsqueda ¿Cómo los conseguiste? ¿Por qué esos datos? ¿Qué información tienen y cual crees que te haga falta o qué podría agregar valor?

# %% [markdown]
# *   Los datos que vamos a utilizar los conseguimos gracias a la pagina web [Kaggle](https://www.kaggle.com/jahnveenarang/cvdcvd-vd).
# *   Vamos a usar todos los datos a nuestra disposicion para responder las preguntas planteadas, es decir, los que posea el Dataset.
# *   Seleccionamos estos datos por la tematica interesante y porque brindaban un buen entendimiento que nos serviria para poder analizarlo mas adelante.
# *   Poseen datos de usuario, edad, sexo, salario estimado anual y si dieron clic y finalmente compraron el producto.
# *   Lo que creo que le faltaria a este conjunto de datos es mas informacion sobre la persona que compra el producto, asi como el tiempo que paso viendo el anuncio publicitario y la ubicacion geografica del mismo (ciudad, pais, etc). Por ultimo, pero no menos importante, sobre el producto en cuestion del cual vio la publicidad.

# %% [markdown]
# # Presentación de las variables del _dataset_
# Describe las variables que componen tu dataset

# %% [markdown]
# **Variables de Dataset:**

# %%
#Como ya cargamos nuestro conjunto de datos anteriormente, lo que vamos a hacer ahora es subirlo y ver que nos muestra la tabla
Ad
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %% [markdown]
# Como podemos ver a simple vista nuestro dataset posee 400 filas y 5 columnas.
#
# Cada columna representa una variable, en este caso se trata de las siguientes:
# *   User ID/N. de identificacion del usuario
# *   Gender/sexo
# *   Age/edad
# *   EstimatedSalary/Salario estimado
# *   Purchased/Comprado

# %% [markdown]
# # Hipótesis inicial
# Formula una hipótesis inicial de cómo crees que influenciarán las distintas variables de tu dataset para responder tu pregunta.

# %% [markdown]
# Retomando mis preguntas, creo que la influencia se va a basar en los siguientes puntos:
#
# *   Las mujeres compran mas.
# *   Las personas con un salario mas alto compran mas.
# *   Los hombres en torno a los 40 años compran mas

# %% [markdown]
# # Análisis exploratorio
#
# Explora un poco tus datos, hazte algunas preguntas extras que te puedan dar claridad sobre el comportamiento de los datos y que puedan ayudarte a entender mejor el problema o el comportamiento del caso a estudiar. Debes hacerte varias preguntas (al menos 3 para el proyecto) y responderlas con gráficos.

# %% [markdown]
# **En esta sección te puedes ayudar de texto y código, recuerda, los gráficos son muy importantes. Haz tu análisis aquí.**

# %%
#Cargamos dos librerias que nos van a ayudar.
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ####Vamos a empezar analizando que tipos de datos tenemos en esta ocasion para cada variable.

# %%
print("La edad es", Ad.Age.dtypes)
print("El sexo es", Ad.Gender.dtypes)
print("El salario estimado es", Ad.EstimatedSalary.dtypes)
print("La compra es", Ad.Purchased.dtypes)
# Out:
# La edad es int64
# El sexo es object
# El salario estimado es int64
# La compra es int64

# %% [markdown]
# ####Vemos como estan separadas las variables de dos datos.

# %%
Ad.Gender.value_counts()
# Out:
# Female    204
# Male      196
# Name: Gender, dtype: int64

# %% [markdown]
# *Hay ligeramente una mayor cantidad de mujeres*

# %%
Ad.Purchased.value_counts()
# Out:
# 0    257
# 1    143
# Name: Purchased, dtype: int64

# %% [markdown]
# *Menos personas terminaron comprando el producto*

# %% [markdown]
# ####Analizamos todas las variables y sus datos con un comando.

# %%
Ad.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %% [markdown]
# *Las primeras conclusiones que podemos sacar es que comienza a tomar los datos desde los 18 años hasta los 60.*
#
# *Luego que la edad promedio es 37 años*
#
# *Que el salario promedio es casi 70 mil dolares*

# %% [markdown]
# ####Ahora vamos a usar graficos para que sea mas dinamico y podamos comprobar lo que vimos anteriormente.

# %%
#Edad
sns.displot(data = Ad, x = "Age")

# %%
#Salario estimado
sns.displot(data = Ad, x = "EstimatedSalary")

# %% [markdown]
# ####Salario respecto del sexo

# %%
sns.factorplot(data = Ad, x = "Gender", y = "EstimatedSalary", size=4, aspect=2)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3723: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.barplot(data = Ad, x = "Gender" , y = "EstimatedSalary")

# %% [markdown]
# *Con estos dos graficos podemos ver que las mujeres poseen un salario mas alto que los hombres.*

# %% [markdown]
# ####Edad respecto del sexo

# %%
sns.factorplot(data = Ad, x = "Gender", y = "Age", size=4, aspect=2)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3723: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# *Con este grafico podemos ver que las mujeres tienen mas edad que los hombres.*

# %% [markdown]
# ####Relaciones con Purchased

# %% [markdown]
# Purchased-Gender

# %%
sns.barplot(data = Ad, x = "Gender" , y = "Purchased")

# %% [markdown]
# *Las mujeres compran mas.*

# %% [markdown]
# Purchased-EstimatedSalary

# %%
sns.barplot(data = Ad, x = "Purchased" , y = "EstimatedSalary")

# %% [markdown]
# *Las personas que compraron luego de ver el anuncio tienen el salario mas alto.*

# %% [markdown]
# Purchased-Age

# %%
sns.barplot(data = Ad, x = "Purchased" , y = "Age")

# %% [markdown]
# *Las personas con mas edad compraron despues de ver el anuncio*

# %% [markdown]
# ####Datos generales respecto de la compra

# %%
sns.pairplot(Ad, hue="Purchased")

# %% [markdown]
# ###Conclusion y respuestas

# %% [markdown]
# Lo que pudimos ver luego de estos graficos es que efectivamente las tres hipotesis que habiamos planteado eran las correctas.

# %% [markdown]
# # Limpieza del _dataset_
#
# En esta etapa limpiamos los datos según lo aprendido en el módulo 2. Recuerda que para cada variable debes definir las cualidades que debe tener, evaluar si las cumple y, en caso que no, tomar una decisión sobre qué hacer en los casos que no se cumplan las cualidades necesarias.

# %% [markdown]
# ####Comprobamos si hay datos nulos.

# %%
Ad.isna().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %% [markdown]
# *No hay ninguno*

# %% [markdown]
# ####Comprobamos si no hay datos atipicos.

# %% [markdown]
# Separamos los graficos, ya que, hay mucha diferencia entre los valores de las variables y no nos permite analizarlos correctamente.

# %%
#Grafico de caja en salario
sns.boxplot(data = Ad["EstimatedSalary"])

# %%
#Grafico de caja en salario
sns.boxplot(data = Ad["Age"])

# %% [markdown]
# *Al parecer no hay ningun dato atipico que escape fuera del rango de confianza.*

# %% [markdown]
# ####Eliminamos las variables que no vamos a usar.

# %%
#Creamos una variable sin la columna de User ID.
Ad_Limpio = Ad[[ "Gender", "Age", "EstimatedSalary", "Purchased"]]

# %%
#Miramos como quedo nuestro nuevo data set
Ad_Limpio
# Out:
#      Gender  Age  EstimatedSalary  Purchased
# 0      Male   19            19000          0
# 1      Male   35            20000          0
# 2    Female   26            43000          0
# 3    Female   27            57000          0
# 4      Male   19            76000          0
# ..      ...  ...              ...        ...
# 395  Female   46            41000          1
# 396    Male   51            23000          1
# 397  Female   50            20000          1
# 398    Male   36            33000          0
# 399  Female   49            36000          1
#
# [400 rows x 4 columns]

# %% [markdown]
# #Realizamos la predicción.

# %%
#Cargamos la libreria que nos permite generar datos de testeo y entrenamiento de manera aleatoria
from sklearn.model_selection import train_test_split

# %%
#Asignamos en X lo que vamos a usar para predecir
x = Ad_Limpio[["Age","EstimatedSalary"]]
#Asignamos lo que vamos a predecir
y = Ad_Limpio["Purchased"]
#Separamos los datos en testeo y entrenamiento
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=1)

# %%
#Cargamos el modelo de Cross Validation
from sklearn.model_selection import GridSearchCV
#Cargamos el modelo de RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
#Asignamos los hiperparametros en el RandomForest para probar cual es mejor
hiperparam = {"n_estimators":[1,2,4,8,15,30,50,80,100], "max_depth":[1,2,3,4], "max_features":[1,2], "bootstrap":[True, False]}

# %%
#Cargamos el modelo con la variable random_forest
random_forest = RandomForestClassifier()

# %%
#Creamos una variable en donde guardamos de a cuantos numeros va a hacer el CrossValidation, en este caso 5
grid = GridSearchCV(estimator=random_forest, param_grid=hiperparam, cv=5)

# %%
#Entrenamos el modelo
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False,
# ...

# %%
#Pedimos que nos muestre los mejores parametros para ver cuales escogio
grid.best_params_
# Out:
# {'bootstrap': True, 'max_depth': 3, 'max_features': 2, 'n_estimators': 100}

# %%
#Le pedimos que nos diga cual fue el mejor resultado con los mejores parametros en entrenamiento
grid.best_estimator_.score(x_train, y_train)
# Out:
# 0.9333333333333333

# %%
#Le pedimos que nos diga cual fue el mejor resultado con los mejores parametros en testeo
grid.best_estimator_.score(x_test, y_test)
# Out:
# 0.88

# %%
#Realizamos una prediccion de una persona de 40 años con un salio de 100 mil
grid.best_estimator_.predict([[40, 100000]])
# Out:
# array([1])

# %% [markdown]
# *Efectivamente las personas un alto salario y alta edad compran luego de ver la publicidad*
